# %%
import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
from openai import OpenAI
from searchwebsite import Website
import gradio as gr

# %%
from langchain.document_loaders import DirectoryLoader, TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.schema import Document
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_chroma import Chroma
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import numpy as np
import plotly.graph_objects as go
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationalRetrievalChain
from langchain.embeddings import HuggingFaceEmbeddings

# %%
#Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# %%
website = Website("https://www.koraaitech.com/")
print(website.title)
print(website.text)
website.links
# Out:
# Home | PremKumar Kora
# Skip to main content
# PremKumar Kora
# Data Scientist & AI Architect
# Home
# AI Innovations Hub
# Intellectual Portfolio
# Education
# Contact
# Published Author  | AI Architect
# ​
# GenAI & LLMops Specialist
# With 25+ years in software technology and AI, I specialize in Artificial Intelligence, Large Language Models (LLMs), and Generative AI solutions for business transformation. My expertise spans AI architecture, machine learning, NLP, predictive analytics, and cloud AI deployment.
# As a Senior Data Scientist & GenAI Architect, I have led projects across industries, implementing LLMOps frameworks, data pipelines, and AI automation systems. My work includes enterprise AI solutions, real-time data analysis, and automated decision-making, leveraging GenAI, prompt engineering, and transformer models.
# I am passionate about developing scalable, real-world AI applications and advancing AI-driven innovations. Currently, I am exploring global opportunities  to contribute to the AI revolution.
# My Achievements
# 2+
# Patent
# ​
# 2+
# ​
# Author
# 22+
# ​
# Publications
# 100+
# Mentoring
# 23+
# Speaker
# Published Articles
# AI Agents
# Specialized AI Intelligence — Vertical AI Agents
# LLM Fine Tuning
# Fine-Tuning Foundational Models: A Guide to Customizing AI for Specific Needs
# Evaluate ML/DL Model
# Evaluating Machine Learning and Deep Learning Models.
# Large Language Models
# Large Language Models and Streaming Large Language Models explained
# Bias and Variance
# Bias and Variance / Overfitting and Underfitting Tradeoffs
# Data Lineage
# You can edit text on your website by double clicking.
# Discriminative vs. Generative Models
# Why and when to use Discriminative vs. Generative Models
# ML Algorithm Vs Model
# Difference Between an ML Algorithm and an ML Model
# Mentor to 100+ Future AI Professionals
# Through technical guidance, career coaching, and project-based learning, I empower mentees to develop AI-driven solutions, optimize ML models, and navigate the evolving landscape of artificial intelligence.
# Get In Touch
# Giving Back to the Community
# Recognized for outstanding contributions and awarded Best Mason of the Year for impactful charitable efforts by
# The Pitt Macdonald Lodge, No.1198.
# Eye camp
# Organized a community Eye Camp, screening 300+ individuals and facilitating cataract surgeries for 70+ needy patients. Ensured access to quality eye care for underprivileged communities, improving their vision and well-being.
# Flood relief camp
# Led a Flood Relief Camp, providing essential aid, food, and medical support to affected families.
# Coordinated efforts to distribute relief materials, ensuring timely assistance to those in need
# Helped in the rehabilitation and support of displaced individuals, focusing on community recovery.
# Recognized for dedication to humanitarian service and commitment to aiding disaster-stricken communities
# Medical camp
# Organized a General Medical Camp for the fisherman community at Irrukkam Island, providing essential healthcare services.
# Facilitated free medical check-ups, consultations, and treatments for individuals with limited access to healthcare.
# Partnered with medical professionals to diagnose and address common health issues among the underserved community
# Request My Resume
# 📩 Enter your email below to receive a copy of my resume directly in your inbox.
# Email
# Subscribe
# PremKumar Kora
# '#thememaincontent, /, /, /AI_hub, /Intellectual_Portfolio, /education, /contact, https://medium.com/@consultkora/specialized-ai-intelligence-vertical-ai-agents-749ad5ca4106, https://medium.com/@consultkora/fine-tuning-foundational-models-a-guide-to-customizing-ai-for-specific-needs-295c8a6222e6, https://medium.com/@consultkora/evaluating-machine-learning-and-deep-learning-models-5a5b17234488, https://medium.com/@consultkora/streaming-large-language-models-f3c59d51a9f0, https://medium.com/@consultkora/bias-and-variance-explained-c1468999b42f, https://medium.com/@consultkora/data-lineage-understanding-its-role-in-modern-data-management-a50822544c76, https://medium.com/@consultkora/why-and-when-to-use-discriminative-vs-generative-models-d3f28e254c3e, https://medium.com/@consultkora/difference-between-an-ml-algorithm-and-an-ml-model-31f9f0a76c51, javascript:;, https://www.linkedin.com/in/premkora/, https://x.com/premkumarkora'

# %%
openai = OpenAI()

# %%
response = openai.responses.create(
    model="o4-mini",
    input=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": (
            "Here’s a list of URLs I’d like you to analyze:\n\n"
            f"{website.links}\n\n"
            "Can you please:\n"
            "1. Use all the links that will be useful for creating a profession resume\n"
            "2. Extract domain names.\n"
            "3. Summarize what kind of content lives at each URL (e.g. blog post, homepage, contact page)."
        )}
    ]
)

# 4. Print out the assistant’s reply
ass_response = response.output_text

# %% [markdown]
# # A system prompt

# %%
system_prompt = "You are an assistant that analyzes the contents of a website \
and provide a resume, look for infomation from other links provided \
Respond in markdown."

# %% [markdown]
# # User Prompt

# %%
user_prompt = f"You are looking at a website titled {website.title}"
user_prompt += "\nThe contents of this website is as follows; \
please create a professional resume pass ATS in markdown. \n\n"
user_prompt += website.text
user_prompt += ass_response

# %% [markdown]
# # sending information to model second time

# %%
response = openai.responses.create(
    model="o4-mini",
    reasoning={"effort": "medium"},
    input=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt }
    ]
)

#print(response.output_text)
#response.choices[0].message.content
display(Markdown(response.output_text))
# Out:
# ```markdown
# # PremKumar Kora
# **Data Scientist & AI Architect**
#
# **Contact**
# Email: [your.email@example.com]
# LinkedIn: https://www.linkedin.com/in/premkora/
# Twitter: https://x.com/premkumarkora
#
# ---
#
# ## Professional Summary
# Published Author and AI Architect with 25+ years of experience in software technology and artificial intelligence. Expert in designing and deploying Generative AI and Large Language Model (LLM) solutions for enterprise transformation. Proven track record leading cross-industry projects, building LLMOps frameworks, data pipelines, real-time analytics and AI automation systems. Passionate about scalable, real-world AI applications, prompt engineering, transformer models and cloud AI deployment.
#
# ---
#
# ## Core Competencies
# - **AI & Machine Learning**: Generative AI, LLMs, NLP, Predictive Analytics, Transformer Models
# - **AI Architecture & Ops**: LLMOps Frameworks, Data Pipeline Design, Model Monitoring, Prompt Engineering
# - **Cloud & Deployment**: AWS SageMaker, Azure ML, GCP AI Platform, Docker, Kubernetes
# - **Programming & Tools**: Python, R, TensorFlow, PyTorch, Scikit-Learn, Apache Airflow
# - **Leadership & Communication**: Technical Strategy, Team Leadership, Mentoring, Public Speaking
#
# ---
#
# ## Professional Experience
#
# **Senior Data Scientist & GenAI Architect**
# Self-Employed / Consultant | 1999 – Present
# - Architected and delivered end-to-end enterprise AI solutions across finance, healthcare, retail and manufacturing sectors.
# - Designed and implemented LLMOps frameworks for continuous fine-tuning, evaluation and deployment of large language models.
# - Built scalable data pipelines and real-time analytics systems to support automated decision-making and customer-facing AI agents.
# - Led prompt engineering initiatives, optimizing model performance and reducing inference latency by 30%.
# - Advised C-suite stakeholders on AI strategy, roadmap development and cloud AI adoption.
#
# ---
#
# ## Achievements
# - 2+ Patents granted in AI & ML technologies
# - 22+ Peer-reviewed Publications and Whitepapers
# - 23+ Invited Speaker engagements at industry conferences and webinars
# - Mentored 100+ future AI professionals in technical skill development and career coaching
#
# ---
#
# ## Publications (Selected)
# - Specialized AI Intelligence—Vertical AI Agents (Medium)
# - Fine-Tuning Foundational Models: A Guide to Customizing AI for Specific Needs (Medium)
# - Evaluating Machine Learning and Deep Learning Models (Medium)
# - Large Language Models and Streaming Large Language Models Explained (Medium)
# - Bias and Variance / Overfitting and Underfitting Tradeoffs (Medium)
# - Understanding Data Lineage and Its Role in Modern Data Management (Medium)
# - Discriminative vs. Generative Models: Why and When to Use (Medium)
# - Difference Between an ML Algorithm and an ML Model (Medium)
#
# ---
#
# ## Mentorship & Leadership
# - Mentored over 100 AI/ML professionals in project-based learning, model optimization and career planning.
# - Developed curriculum and delivered workshops on NLP, model evaluation metrics and ethical AI practices.
#
# ---
#
# ## Community Involvement
# - **Best Mason of the Year**, Pitt Macdonald Lodge No.1198 – Awarded for outstanding charitable contributions
# - **Eye Camp Organizer** – Screened 300+ individuals; facilitated 70+ cataract surgeries for underprivileged communities
# - **Flood Relief Camp Leader** – Coordinated distribution of food, medical aid and rehabilitation support to displaced families
# - **Medical Camp Coordinator** – Provided free healthcare services to the fisherman community on Irukkam Island
#
# ---
#
# ## Education
# Details available upon request
#
# ```

# %%
website = Website("https://www.aviva.co.uk/")
print(website.title)
print(website.text)
website.links
# Out:
# Insurance, Savings, Investments, Retirement and Health - Aviva
# Skip to content
# Personal
# Business
# Contact us
# Menu
# - skip to menu
# Log in
# - skip to log in
# Search
# - skip to search
# 5 Star car, home and travel insurance
# When you insure with Aviva Signature, you can relax knowing you’re covered with a Defaqto 5 Star rated product.
# Motor insurance
# Home insurance
# Travel insurance
# Car
# insurance
# More information
# for Car
# insurance
# Get a quote
# Get a car insurance quote
# Retrieve a quote
# Retrieve a car insurance quote
# Make a claim
# Make a car insurance claim
# I’m an existing customer
# I’m an existing car insurance customer
# Home
# insurance
# More information
# for Home
# insurance
# Get a quote
# Get a home insurance quote
# Retrieve a quote
# Retrieve a home insurance quote
# Make a claim
# Make a home insurance claim
# I’m an existing customer
# I’m an existing home insurance customer
# Life
# insurance
# More information
# for Life
# insurance
# Get a quote
# Learn about life insurance and get a quote
# Make a claim
# Make a life insurance claim
# Over 50 life insurance
# Learn about over 50 life insurance and get a quote
# I’m an existing customer
# I'm an existing life insurance customer
# Pensions and
# investments
# More information
# for Pensions and
# investments
# Our pension
# Learn about our pension and apply
# Savings accounts
# Learn about savings accounts and contact us
# Our ISA
# Learn about our stocks and shares ISA and apply
# I’m an existing customer
# I'm an existing customer with a pension, investments or retirement product
# Health
# insurance
# More information
# for Health
# insurance
# Get a quote
# Learn about health insurance and get a quote
# Call us
# Call us for a health insurance quote
# Make a claim
# Learn about how to make a claim
# I’m an existing customer
# I'm an existing health insurance customer
# Products, useful tools and information
# Motor Insurance
# Car Insurance
# Multi Car Insurance
# Electric Car Insurance
# Van Insurance – personal cover
# Business vehicle and van insurance
# Temporary car insurance
# Breakdown cover
# Learner Driver Insurance
# Classic Car Insurance
# Motorhome and Campervan Insurance
# Aviva Private Clients
# All motor insurance products
# Home Insurance
# Home Insurance
# Contents Insurance
# Buildings Insurance
# Tenants and Renters Insurance
# Landlord Insurance
# Aviva Private Clients
# Life Cover and Protection
# Life Insurance
# Critical Illness Cover
# Over 50s Life Insurance
# Income Protection Insurance
# Free Parent Life Cover
# Life insurance calculator
# Aviva Trusts
# Existing customers – manage your life cover
# View our life cover products
# Health Insurance
# Health insurance
# Diagnostics insurance
# Business health, protection and wellbeing
# Business health insurance for 2-249 employees
# Business health insurance for 250+ employees
# Practitioner Zone
# Hospital Zone
# Health adviser website
# Existing customers – manage your health products
# All health insurance products
# More Insurance
# Travel Insurance
# Single trip travel insurance
# Annual multi trip travel insurance
# Pet Insurance
# Accidental Death Insurance
# Accidental Permanent Injury Insurance
# Hospital Cash Plan
# Business Public Liability Insurance
# Business Buildings and Contents Insurance
# All insurance products
# Investments
# Aviva Stocks & Shares ISA
# Wealthify
# Wealthify JISA
# Transfer your ISA
# Aviva Investment Account
# Savings accounts
# Aviva Select Investment bond
# With-profits investment funds
# ISA Investment calculator
# Financial advice
# Existing customers - manage your investments
# All investment products
# Retirement
# Aviva Pension
# Transfer your pension
# Pension annuity (guaranteed income for life)
# Income drawdown (flexible income)
# Equity release
# Lifetime care
# Shape my future tool
# My retirement planner
# Equity release calculator
# All tools and calculators
# Financial advice
# Existing customers – manage your retirement
# All retirement products
# Cover that keeps up with you
# From the health of you and your loved ones to the protection of the home you live in, and even the car you drive around. If it matters to you, it matters to us.
# Join the 20.5 million others who trust us with the things that matter most
# Footnote
# [1]
# There’s a reason we’ve been around for more than 325 years – our customers believe in us.
# We walk the talk – we put money back in your pockets
# We don’t just say we’ll help, we do it. In 2024 we paid out £29.3 billion in benefits and claims.
# Footnote
# [2]
# We’re here for you at every stage of life
# We'll help point you in the right direction, giving you a helping hand through the good times and the tough times.
# Get health and money insights with Aviva Score
# Answer a few questions about your lifestyle and finances, and we’ll help you with solutions and tasks to help you reach your financial and health goals.
# Discover Aviva Score
# about Get health and money insights with Aviva Score
# Make a claim with us
# Understand more about how to make a claim with us, whether that’s on your car insurance, your home, or even your health.
# Explore claims
# about Make a claim with us
# Get help with accessibility
# From learning how to adapt our website to suit to your needs, to changing the way we communicate with you over the phone and in writing, we want to show up right for all our customers.
# Learn more about how we can support you
# about Get help with accessibility
# A helping hand to lead you where you want to go
# We know our stuff, and we want to share it with our customers. We’ve got plenty of guides and tips within our knowledge centres to help shed some more light on what we offer, why we offer it, and how you can get covered with us.
# Explore life
# Visit our Life knowledge centre to learn more about how life insurance works and whether it might be right for you.
# Life knowledge centre
# about Explore life
# Explore health
# Our health knowledge centre is a hive of information from our clinical experts, from musculoskeletal complaints to long-term conditions and menopause, and our best tips on your wellbeing.
# Health knowledge centre
# about Explore health
# Explore motor
# Learn everything you need to know about vehicle cover from our motor knowledge centre.
# Motor knowledge centre
# about Explore motor
# Learn about Aviva Pension (SIPPs)
# SIPPs (Self invested personal pension) don’t have to be overcomplicated. Answer all your questions about SIPPs and find out what you need to know with our guides.
# SIPP knowledge centre
# about Learn about Aviva Pension (SIPPs)
# Back to start of main content
# Footnotes
# Across our
# core markets of the UK, Ireland and Canada
# , of which 2.4 million are in
# Canada
# .
# Correct as at 31 December 2024
# Search
# Search site
# Search
# Login or register
# Log in
# or
# Register
# Your account
# Hi
# ,
# Your account
# Your policies
# Aviva Community Fund
# Your profile
# Security details
# Shareholder Centre
# Log out
# Get support
# Contact us
# Make a claim
# Manage your policy
# Site navigation
# Insurance
# Motor
# Car insurance
# Get a car quote
# Retrieve a car quote
# Electric car insurance
# Multi car insurance
# Van insurance
# Breakdown cover
# Car knowledge centre
# View all motor products
# Motor contact us
# Home
# Home insurance
# Get a home quote
# Retrieve a home quote
# Contents insurance
# Buildings insurance
# Landlord insurance
# Tenants and Renters insurance
# Home knowledge centre
# View all home products
# Home contact us
# Life
# Life insurance
# Get a life quote
# Retrieve a life quote
# Over 50 life insurance
# Critical illness cover
# Income protection insurance
# Free parent life cover
# View all our life cover options
# Life contact us
# More
# Health insurance
# Travel insurance
# Personal accident insurance
# Pet insurance
# New
# Business insurance
# Electric car hub
# Aviva Score
# Existing customers
# Make a claim
# Renew policy
# Manage policy
# Log in to MyAviva
# Register for MyAviva
# Multi car
# Multi car covers up to 5 vehicles registered at the same address. Discount not available on optional extras or in addition to other discounts.
# Find out more
# View all insurance products
# Help and resources
# FAQs
# Useful info
# Contact us
# Investments
# Investments
# Aviva Pension
# Stocks & Shares ISA
# Wealthify Junior ISA
# Investment Account
# Investment funds
# Share dealing
# Aviva Wealth
# View all investments products
# Investments contact us
# Savings
# Savings accounts
# Fixed rate accounts
# Notice accounts
# Easy access accounts
# View all savings products
# Tools and advice
# ISA calculator
# Investment calculator
# Compound interest calculator
# Personal Savings Allowance calculator
# Financial advice
# View all tools and calculators
# Existing customers
# Log in to MyAviva
# Register for MyAviva
# Manage investments
# View all investments and savings products
# Help and resources
# Useful info
# Contact us
# Retirement
# Pensions
# Aviva Pension
# Workplace pension
# Pension transfer
# Find and combine pensions
# Pension tracing
# Consolidate your pensions
# View all pension products
# Pension contact us
# Retirement
# Pension drawdown
# Pension annuity
# Immediate life annuity
# Lifetime Care
# Equity release
# View all retirement products
# Retirement contact us
# Tools and advice
# Pension calculator
# Annuity calculator
# Equity release calculator
# Pension tax calculator
# Inheritance tax calculator
# Financial advice
# View all tools and calculators
# Existing customers
# Log in to MyAviva
# Register for MyAviva
# Manage pension
# Manage annuity
# Manage equity release plan
# View all pension and retirement products
# Help and resources
# Guides and tips
# Useful info
# Contact us
# Health
# Health cover
# Health insurance
# Diagnostics insurance
# Cover add-ons
# View all health products
# Health contact us
# Know more
# Understanding medical underwriting types
# Health insurance add-ons
# Cancer care
# COVID-19
# Aviva Score
# Existing customers
# Make a health claim
# Make a diagnostics claim
# Manage health insurance
# Log in to MyAviva
# Register for MyAviva
# Tools and calculators
# BMI calculator
# BMR calculator
# Alcohol units calculator
# View all health products
# Help and resources
# Guides and tips
# FAQs
# Useful info
# Contact us
# Help and resources
# Help and support
# FAQs
# Contact us
# Footer
# Useful information
# Accessibility
# Contact Aviva
# Make a claim
# Protect yourself from fraud
# Frequently asked questions
# About us
# About Aviva
# Climate-related Disclosure (TCFD) Reports
# Customer Data Charter
# Careers
# Other links
# Aviva corporate
# Intermediary site
# Risk Solutions
# Quotemehappy.com
# General Accident
# Social
# Facebook
# Twitter
# YouTube
# Legal
# Legal
# Privacy Policy
# Cookie Policy
# Modern Slavery Statement
# Site map
# Manage cookies
# Copyright
# WC06444 05/2025
# © 2025 Aviva
# '#main, https://www.aviva.co.uk/business/, /help-and-support/contact-us/, https://www.aviva.co.uk/, #nav, #login, #search, /insurance/motor/car-insurance/, /insurance/home-products/home-insurance/, /insurance/travel-insurance/, /insurance/motor/car-insurance/, https://www.direct.aviva.co.uk/quote/direct/motor, https://www.direct.aviva.co.uk/quote/Direct/Motor/Quote/RetrieveQuoteClientSearch, https://www.direct.aviva.co.uk/MyClaims/Public/Motor, /help-and-support/contact-us/motor-insurance/, /insurance/home-products/home-insurance/, https://www.direct.aviva.co.uk/quote/Direct/Home, https://www.direct.aviva.co.uk/quote/Direct/Home/Quote/RetrieveQuoteClientSearch, /help-and-support/claims/home-claims/, /help-and-support/contact-us/home-insurance/, /insurance/life-products/life-insurance/, /insurance/life-products/life-insurance/, /help-and-support/claims/life-claims/, /insurance/life-products/over-50-life-insurance/, /help-and-support/contact-us/life-insurance/, /investments/, /retirement/aviva-pension/, /investments/savings-accounts/, /investments/stocks-and-shares-isa/, /help-and-support/contact-us/pensions-and-retirement/, /health/health-products/health-insurance/, /health/health-products/health-insurance/, /health/health-products/health-insurance/#quote-contact-us, /help-and-support/claims/health-claims/, /help-and-support/contact-us/health-insurance/, /insurance/motor/car-insurance/, /insurance/motor/multi-car-insurance/, /insurance/motor/electric-car-insurance/, /insurance/motor/van-insurance/, https://www.aviva.co.uk/business/insurance/business-vehicle-insurance/, /insurance/motor/short-term-car-insurance/, /insurance/motor/breakdown-cover/, /insurance/motor/learner/, /insurance/motor/classic-car/, /insurance/motor/campervan-insurance/, /aviva-private-clients/, /insurance/motor/, /insurance/home-products/home-insurance/, /insurance/home-products/contents-insurance/, /insurance/home-products/buildings-insurance/, /insurance/home-products/tenants-insurance/, /insurance/home-products/landlord-insurance/, /aviva-private-clients/, /insurance/life-products/life-insurance/, /insurance/life-products/critical-illness-cover/, /insurance/life-products/over-50-life-insurance/, /insurance/life-products/income-protection-insurance/, /insurance/life-products/free-parent-life-cover/, /insurance/life-products/life-insurance/life-insurance-calculator/, /insurance/life-products/life-insurance/aviva-trusts/, /help-and-support/managing-your-policy/life-insurance/, /insurance/life-products/, /health/health-products/health-insurance/, /health/health-products/diagnostics-insurance/, https://www.aviva.co.uk/business/health-protection-wellbeing/, https://www.aviva.co.uk/business/health-protection-wellbeing/health-insurance/private-medical-insurance-sme/, https://www.aviva.co.uk/business/health-protection-wellbeing/health-insurance/private-medical-insurance-corp/, https://www.aviva.co.uk/health-insurance/practitioner-zone/, https://www.aviva.co.uk/hospital-zone/, https://connect.avivab2b.co.uk/health/, /help-and-support/managing-your-policy/health/, /health/health-products/, /insurance/travel-insurance/, /insurance/travel-insurance/single-trip-travel-insurance/, /insurance/travel-insurance/annual-multi-trip-travel-insurance/, /insurance/pet-insurance/, /insurance/personal-accident/accidental-death-insurance/, /insurance/personal-accident/accidental-permanent-injury-insurance/, /insurance/personal-accident/hospital-cash-plan/, https://www.aviva.co.uk/business/insurance/public-liability-insurance/, https://www.aviva.co.uk/business/insurance/buildings-and-contents-insurance/, /insurance/, /investments/stocks-and-shares-isa/, /investments/wealthify/, /investments/wealthify-junior-isa/, /investments/transfer-an-isa/, /investments/investment-account/, /investments/savings-accounts/, /investments/select-investment/, /help-and-support/managing-your-policy/investments/with-profits-investment/, https://www.direct.aviva.co.uk/myfuture/IsaInvestmentCalculator,  ...

# %%
openai = OpenAI()

# %%
response = openai.responses.create(
    model="o4-mini",
    input=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": (
            "Here’s a list of URLs I’d like you to analyze:\n\n"
            f"{website.links}\n\n"
            "Can you please:\n"
            "1. Use all the links that will be useful for creating a clean description of the company\n"
            "2. Extract domain names.\n"
            "3. Summarize what kind of content lives at each URL (e.g. blog post, homepage, contact page)."
        )}
    ]
)

# 4. Print out the assistant’s reply
ass_response = response.output_text

# %%
system_prompt = "You are an assistant that analyzes the contents of a website \
and provide a professional description of the company in 5,000 words plain text."

# %%
user_prompt = f"You are looking at a website titled {website.title}"
user_prompt += "\nThe contents of this website is as follows; \
please create a professional company description of 5,000 words\n\n"
user_prompt += website.text
user_prompt += ass_response

# %%
response = openai.responses.create(
    model="o4-mini",
    reasoning={"effort": "medium"},
    input=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt }
    ]
)

#print(response.output_text)
#response.choices[0].message.content
#display(Markdown(response.output_text))
# Out:
# [Company Description – Aviva plc]
#
# Introduction
# Aviva plc is a leading multinational insurance, savings, investments, retirement and health provider, headquartered in London, United Kingdom. Serving more than 20.5 million customers across its core markets in the UK, Ireland and Canada, Aviva offers an extensive range of personal and business products that protect people, their families, their assets and their futures. With over 325 years of heritage, Aviva has built a reputation for financial strength, innovation, customer service and long-term value creation. In 2024 alone, Aviva paid out £29.3 billion in benefits and claims, demonstrating its commitment to keeping the promises made to its customers.
#
# History and Heritage
# Aviva’s origins date back to the late 17th and early 18th centuries, encompassing a series of mutual societies and proprietary businesses that merged and evolved over time. Landmark institutions in its lineage include Norwich Union (founded 1797), Commercial Union (1861) and General Accident (1885). In 2000, Commercial Union and Norwich Union merged to form CGU plc; two years later CGU combined with General Accident to form CGNU. In 2002 the business was rebranded as Aviva, a name derived from the Latin word “viva,” meaning to be alive. This name change symbolized Aviva’s commitment to vitality, resilience and innovation. Throughout its history, Aviva has demonstrated an ability to adapt to changing market conditions, regulatory environments and customer needs.
#
# Mission, Vision and Values
# Aviva’s mission is to protect and enrich the lives of its customers by delivering outstanding products and services with integrity, expertise and care. Guided by a clear set of values—Trust, Simplicity, One Aviva and Customer First—Aviva strives to create a culture in which every colleague is empowered to act ethically, collaboratively and responsively. Aviva’s vision is to be the most trusted insurer and long-term savings provider, recognized for its customer orientation, digital capabilities and positive social impact. Its strategic priorities emphasize sustainable growth, operational excellence, digital transformation and meaningful engagement with customers and communities.
#
# Global Footprint and Customer Base
# Aviva operates primarily in three core markets: the United Kingdom, Ireland and Canada. As at 31 December 2024, Aviva served more than 20.5 million personal and business customers, of whom approximately 2.4 million were in Canada. In the UK it provides insurance and savings solutions across virtually every customer segment, while in Ireland it offers motor, home and life cover through both direct and intermediary channels. In Canada, Aviva delivers personal lines and commercial insurance through a network of brokers, leveraging its global expertise in risk management and underwriting. Across these markets, Aviva employs more than 30,000 colleagues and works with tens of thousands of intermediaries and partners.
#
# Product Portfolio
#
# 1. Personal Insurance
# Aviva Signature Car, Home and Travel Insurance
# Aviva Signature is the Company’s flagship personal lines brand, comprising motor, home and travel products that have been rated 5 Star by Defaqto, an independent financial product reviewer. Aviva Signature car insurance includes comprehensive cover, accident forgiveness, courtesy car provision, uninsured driver promise and optional extras such as legal protection. Home insurance under the Signature banner features accidental damage cover, replacement locks, trace and access cover, and alternative accommodation. Travel insurance offers multi-trip, single-trip, backpacker and business travel options, together with medical emergency cover, cancellation cover and baggage protection.
#
# Motor Insurance
# In addition to the Signature range, Aviva’s motor insurance portfolio includes specialist products: multi-car insurance (covering up to five vehicles at the same address), electric car insurance, learner driver insurance, classic vehicle insurance, temporary cover (e.g., five-day policy), motorhome and campervan insurance, van insurance for personal use and business vehicles, and breakdown assistance.
#
# Home Insurance
# Aviva offers building, contents and combined home insurance. Customers can choose cover tailored to owner-occupiers, landlords, tenants and renters. Policies include optional extras such as home emergency assistance, legal expenses cover and home technology protection.
#
# Travel Insurance
# Single-trip and annual multi-trip travel policies accommodate leisure and business travellers. Aviva’s travel products provide medical emergency cover, trip cancellation, curtailment, baggage loss, personal liability and enhanced sections for winter sports, cruise cover and golf.
#
# Life and Protection
# Aviva’s life insurance portfolio comprises term life policies, whole of life cover, over-50s life insurance, critical illness cover, income protection and free parent life cover. Customers can obtain a quote online or via telephone and benefit from flexible payment options, guaranteed premiums, accelerated critical illness payouts, and the ability to write policies in trust.
#
# Health Insurance
# Aviva provides private medical insurance (PMI) and diagnostics insurance. Personal health cover includes inpatient and outpatient treatment, cancer cover, mental health support, virtual GP services and access to Aviva’s Hospital Zone network of provider hospitals. Aviva also offers business health solutions for employers with two to 249 employees (SME cover) and for larger corporate groups (250+), which may incorporate wellness programs, occupational health services and employee assistance programs.
#
# Pet Insurance and Personal Accident
# Aviva’s pet insurance covers dogs, cats and horses for veterinary fees, death from illness or injury, third-party liability (for dogs), and boarding fees. Personal accident products provide lump-sum benefits for accidental death, permanent disability and hospital cash payments.
#
# 2. Business Insurance
# Aviva supports businesses across a wide spectrum of industries. Products include commercial vehicle and fleet insurance; public liability, employers’ liability and professional indemnity; business property cover (buildings and contents); business interruption insurance; and specialist covers such as commercial cyber insurance. Aviva Risk Solutions offers risk management consultancy, engineering surveys and tailored programs for high-net-worth and complex risks.
#
# 3. Savings and Investments
# Savings Accounts
# Aviva’s savings proposition comprises easy access, fixed rate and notice accounts, featuring competitive interest rates, online and branch-based application and flexible withdrawal options.
#
# Individual Savings Accounts (ISAs)
# Aviva Stocks & Shares ISAs, Junior ISAs and Cash ISAs enable tax-efficient investing in a broad range of funds. Aviva’s ISA Investment Calculator helps customers project growth over time. Transfer services allow customers to move existing ISAs into Aviva portfolios.
#
# Investment Products and Platforms
# Aviva Wealth and Aviva Investment Account give retail investors direct access to unit trusts, OEICs and Exchange-Traded Funds (ETFs). With-profits funds, characterized by smoothing of returns and potential for annual bonuses, remain a core offering. Wealthify, Aviva’s digital investment service, provides risk-based portfolios managed by experts, both for adults and junior savers.
#
# With-Profits Investment Funds
# Aviva’s With-Profits funds invest in diversified portfolios of equities, bonds and alternative assets. Fund bonuses are declared annually, reflecting investment performance and smoothing to protect customers from market volatility.
#
# 4. Retirement and Pensions
# Aviva Pension (Workplace and Personal)
# Aviva’s pension solutions include workplace defined contribution (DC) schemes, master trusts and group personal pensions, as well as personal self-invested personal pensions (SIPPs). The “Shape My Future” and “My Retirement Planner” digital tools guide customers through contribution planning, retirement income options and tax implications.
#
# Retirement Income Options
# At retirement, customers can choose guaranteed income for life via a pension annuity or flexible income through income drawdown. Aviva offers a range of annuity products, including enhanced annuities for customers with health or lifestyle factors, and fixed, escalating and variable options. Income Drawdown products allow continued investment growth potential with regular or ad hoc withdrawals.
#
# Equity Release and Lifetime Care
# Through equity release solutions, Aviva helps homeowners aged 55+ access tax-free lump sums or regular payments secured against their property. Lifetime Care, a proprietary service, combines financial planning, care needs assessment and equity release to fund long-term care costs.
#
# Digital Tools and Calculators
# Aviva provides a suite of online calculators: pension income, annuity rate, equity release, ISA growth, compound interest and inheritance tax calculators. These tools empower customers to model scenarios and make informed decisions.
#
# Distribution Channels
# Aviva employs a multi-channel distribution strategy: direct online, telephone sales, branch networks (in some markets), intermediaries (brokers, financial advisers, wealth managers) and bancassurance partnerships. The MyAviva online portal and mobile app allow customers to get quotes, purchase policies, retrieve existing quotes, manage policies, make renewals and submit claims. Aviva’s direct quoting system provides instant motor, home and life insurance quotes, retrieval of saved quotes and completion of online applications.
#
# Claims Handling and Customer Support
# Aviva prides itself on efficient, empathetic claims service. In 2024, claims payments totaled £29.3 billion, reinforcing Aviva’s financial capacity to meet its obligations. Customers can report and track claims online or via telephone for motor, home, life and health policies. Specialist teams manage complex commercial claims. Aviva’s “uninsured driver promise” ensures hit-and-run victims do not bear the cost, while the “courtesy car” benefit provides mobility following an accident. Accessibility support—ranging from website adaptation to alternative communication formats—ensures that customers with disabilities receive appropriate assistance.
#
# Digital Innovation and Insights
# Aviva Score
# Aviva Score is an interactive health and financial wellbeing tool. By answering questions on lifestyle, spending and goals, customers receive tailored insights, recommended tasks and signposts to relevant products or content.
#
# Knowledge Centres and Educational Content
# Aviva’s online knowledge centres cover life insurance, motor cover, home protection, health insights, pension planning and SIPPs. Written by subject-matter experts, these resources demystify product features, explain underwriting processes and offer practical tips.
#
# Personalisation and Data Analytics
# Aviva leverages real-time data, telematics (for auto insurance), AI-driven underwriting and predictive analytics to personalize pricing, detect fraud, streamline claims processing and enhance customer journeys. The “Electric Car Hub” offers dedicated guidance on insuring electric vehicles, while telematics-based policies reward safer driving with premium discounts.
#
# Corporate Responsibility and Sustainability
# Climate-Related Financial Disclosures
# Aviva publishes annual climate-related disclosure reports aligned to the Task Force on Climate-related Financial Disclosures (TCFD). These outline Aviva’s approach to managing climate risk, achieving net-zero operations by 2040, reducing financed emissions and supporting the transition to a low-carbon economy.
#
# Community Investment
# Through the Aviva Community Fund, customers and employees nominate and vote for local charities and social enterprises to receive grants. In recent years millions of pounds have been distributed to projects promoting health, inclusion, education and environmental resilience.
#
# Diversity, Equity and Inclusion
# Aviva fosters an inclusive workplace where colleagues from diverse backgrounds can thrive. Employee resource groups, unconscious bias training and inclusive leadership programs support retention and career development for under-represented groups.
#
# Corporate Governance and Ethics
# Aviva operates under a robust governance framework, with an independent Board of Directors, Audit Committee, Risk Committee and Remuneration Committee. The Code of Conduct, Customer Data Charter, Modern Slavery Statement and Privacy Policy reflect Aviva’s commitment to ethical business practices, data protection and human rights.
#
# Financial Strength and Performance
# As a public limited company listed on the London Stock Exchange, Aviva maintains a strong capital position, prudent reserving and a diversified portfolio of underwriting and investment activities. Ratings from major agencies (e.g., A- from S&P, A2 from Moody’s) attest to Aviva’s creditworthiness. Annual reports detail premium income, net earned premiums, combined operating ratios, investment returns and solvency capital requirements.
#
# Strategic Outlook and Future Priorities
# Aviva aims to accelerate its digital transformation, simplify operations, optimize capital allocation and deepen customer engagement. Key strategic initiatives include:
#  • Expanding usage-based insurance and telematics offerings.
#  • Enhancing digital distribution via partnerships, APIs and embedded insurance.
#  • Growing wealth management services and digital investment platforms.
#  • Scaling health and wellbeing solutions, including virtual care and diagnostic services.
#  • Pursuing selective bolt-on acquisitions to strengthen core capabilities.
#  • Advancing sustainability-linked products such as green car insurance discounts and property underwriting that incentivizes energy efficiency.
#
# Conclusion
# With a heritage spanning more than three centuries, Aviva has evolved into a modern, digitally driven insurer and long-term savings provider. Its broad product suite—ranging from motor, home and travel insurance to life protection, health cover, savings accounts, ISAs, pensions, annuities, equity release and business covers—addresses the full spectrum of personal and corporate risk and financial planning needs. Aviva combines financial strength with customer-centric design, leveraging data analytics, digital tools and expert knowledge to deliver tailored solutions. Guided by values of trust, simplicity and customer focus, Aviva continues to invest in innovation, sustainability and community impact, ensuring that it remains the insurer and long-term savings partner of choice for millions of customers across the UK, Ireland and Canada.

# %%
# Your text to write
text = response.output_text

# Open (or create) output.txt for writing, in UTF-8
with open("output.txt", "w", encoding="utf-8") as f:
    f.write(text)

print("Text has been written to output.txt")
# Out:
# Text has been written to output.txt

# %%
# 1. Read your file
with open("output.txt", "r", encoding="utf-8") as f:
    full_text = f.read()

# 2. Wrap it in a Document (so split_documents knows what to split)
doc = Document(page_content=full_text, metadata={"source": "output.txt"})

# 3. Create and run the splitter
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = text_splitter.split_documents([doc])

# `chunks` is now a list of Document objects, each with up to 1000 chars
for i, chunk in enumerate(chunks):
    print(f"── chunk {i} ({len(chunk.page_content)} chars) ──")
    print(chunk.page_content[:200].replace("\n", " "), "…\n")
# Out:
# ── chunk 0 (712 chars) ──
# [Company Description – Aviva plc]  Introduction   Aviva plc is a leading multinational insurance, savings, investments, retirement and health provider, headquartered in London, United Kingdom. Serving …
#
# ── chunk 1 (794 chars) ──
# History and Heritage   Aviva’s origins date back to the late 17th and early 18th centuries, encompassing a series of mutual societies and proprietary businesses that merged and evolved over time. Land …
#
# ── chunk 2 (715 chars) ──
# Mission, Vision and Values   Aviva’s mission is to protect and enrich the lives of its customers by delivering outstanding products and services with integrity, expertise and care. Guided by a clear s …
#
# ── chunk 3 (778 chars) ──
# Global Footprint and Customer Base   Aviva operates primarily in three core markets: the United Kingdom, Ireland and Canada. As at 31 December 2024, Aviva served more than 20.5 million personal and bu …
#
# ── chunk 4 (781 chars) ──
# Product Portfolio    1. Personal Insurance   Aviva Signature Car, Home and Travel Insurance   Aviva Signature is the Company’s flagship personal lines brand, comprising motor, home and travel products …
#
# ── chunk 5 (712 chars) ──
# Motor Insurance   In addition to the Signature range, Aviva’s motor insurance portfolio includes specialist products: multi-car insurance (covering up to five vehicles at the same address), electric c …
#
# ── chunk 6 (702 chars) ──
# Travel Insurance   Single-trip and annual multi-trip travel policies accommodate leisure and business travellers. Aviva’s travel products provide medical emergency cover, trip cancellation, curtailmen …
#
# ── chunk 7 (843 chars) ──
# Health Insurance   Aviva provides private medical insurance (PMI) and diagnostics insurance. Personal health cover includes inpatient and outpatient treatment, cancer cover, mental health support, vir …
#
# ── chunk 8 (730 chars) ──
# 2. Business Insurance   Aviva supports businesses across a wide spectrum of industries. Products include commercial vehicle and fleet insurance; public liability, employers’ liability and professional …
#
# ── chunk 9 (992 chars) ──
# Individual Savings Accounts (ISAs)   Aviva Stocks & Shares ISAs, Junior ISAs and Cash ISAs enable tax-efficient investing in a broad range of funds. Aviva’s ISA Investment Calculator helps customers p …
#
# ── chunk 10 (839 chars) ──
# 4. Retirement and Pensions   Aviva Pension (Workplace and Personal)   Aviva’s pension solutions include workplace defined contribution (DC) schemes, master trusts and group personal pensions, as well  …
#
# ── chunk 11 (584 chars) ──
# Equity Release and Lifetime Care   Through equity release solutions, Aviva helps homeowners aged 55+ access tax-free lump sums or regular payments secured against their property. Lifetime Care, a prop …
#
# ── chunk 12 (555 chars) ──
# Distribution Channels   Aviva employs a multi-channel distribution strategy: direct online, telephone sales, branch networks (in some markets), intermediaries (brokers, financial advisers, wealth mana …
#
# ── chunk 13 (967 chars) ──
# Claims Handling and Customer Support   Aviva prides itself on efficient, empathetic claims service. In 2024, claims payments totaled £29.3 billion, reinforcing Aviva’s financial capacity to meet its o …
#
# ── chunk 14 (717 chars) ──
# Knowledge Centres and Educational Content   Aviva’s online knowledge centres cover life insurance, motor cover, home protection, health insights, pension planning and SIPPs. Written by subject-matter  …
#
# ── chunk 15 (984 chars) ──
# Corporate Responsibility and Sustainability   Climate-Related Financial Disclosures   Aviva publishes annual climate-related disclosure reports aligned to the Task Force on Climate-related Financial D …
#
# ── chunk 16 (843 chars) ──
# Corporate Governance and Ethics   Aviva operates under a robust governance framework, with an independent Board of Directors, Audit Committee, Risk Committee and Remuneration Committee. The Code of Co …
#
# ── chunk 17 (748 chars) ──
# Strategic Outlook and Future Priorities   Aviva aims to accelerate its digital transformation, simplify operations, optimize capital allocation and deepen customer engagement. Key strategic initiative …
#
# ── chunk 18 (858 chars) ──
# Conclusion   With a heritage spanning more than three centuries, Aviva has evolved into a modern, digitally driven insurer and long-term savings provider. Its broad product suite—ranging from motor, h …

# %%
embeddings = OpenAIEmbeddings()
if os.path.exists(db_name):
    Chroma(persist_directory=db_name, embedding_function=embeddings).delete_collection()
vectorstore = Chroma.from_documents(documents=chunks, embedding=embeddings, persist_directory=db_name)
print(f"Vectorstore created with {vectorstore._collection.count()} documents")
# Out:
# Vectorstore created with 19 documents

# %%
llm = ChatOpenAI(temperature=0.7, model_name=MODEL)
memory = ConversationBufferMemory(memory_key='chat_history', return_messages=True)
retriever = vectorstore.as_retriever()
conversation_chain = ConversationalRetrievalChain.from_llm(llm=llm, retriever=retriever, memory=memory)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17124\2669631352.py:2: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory(memory_key='chat_history', return_messages=True)

# %%
query = "Where is Aviva Located?"
result = conversation_chain.invoke({"question": query})
print(result["answer"])
# Out:
# Aviva is headquartered in London, United Kingdom.

# %%
memory = ConversationBufferMemory(memory_key='chat_history', return_messages=True)
conversation_chain = ConversationalRetrievalChain.from_llm(llm=llm, retriever=retriever, memory=memory)

# %%
def chat(question, history):
    result = conversation_chain.invoke({"question": question})
    return result["answer"]

# %%
view = gr.ChatInterface(
    fn=chat,
    type="messages",
    title="Aviva Q&A",            # <-- this sets the page <title> and header text
).launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7868
# * Running on public URL: https://107f7f2af08f467b25.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://107f7f2af08f467b25.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
